# %% [markdown]
# ## Global Stock Market Time Series Comparison
# ### US - S&P500, Europe - EURONEXT, Brazil – BOVESPA, Hong Kong - HSI

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import pylab
# %matplotlib inline
import datetime as dt
from __future__ import division, print_function, unicode_literals

pd.set_option("display.max_columns", 100)

# %% [markdown]
# ### Initial look at Euronext data
#
# A lot of missing values for the volume, we will not use this column.
#
# But clean data.

# %%
euronext_df = pd.read_csv("euronext.csv", encoding = "utf8")
euronext_df.head()
# Out:
#          Date        Open        High         Low       Close  Volume  \
# 0  2016-10-20  894.450012  897.369995  888.270020  895.109985       0
# 1  2016-10-19  891.250000  894.630005  887.979980  893.200012       0
# 2  2016-10-18  885.039978  892.039978  884.849976  890.109985       0
# 3  2016-10-17  881.460022  884.880005  878.599976  880.150024       0
# 4  2016-10-14  874.840027  888.880005  874.789978  884.549988       0
#
#     Adj Close
# 0  895.109985
# 1  893.200012
# 2  890.109985
# 3  880.150024
# 4  884.549988

# %%
euronext_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4303.000000  4303.000000  4303.000000  4303.000000  4.303000e+03
# mean    764.865235   769.284736   759.886435   764.719805  1.572748e+08
# std     156.955172   156.413576   157.505500   156.977364  1.657864e+08
# min     427.600006   436.519989   419.489990   419.950012  0.000000e+00
# 25%     639.904999   644.144989   635.244995   639.404998  0.000000e+00
# 50%     754.260010   758.729980   749.820007   754.700012  1.644566e+08
# 75%     879.195007   884.774994   872.830017   878.984985  2.858348e+08
# max    1147.839966  1147.839966  1147.839966  1147.839966  1.095260e+09
#
#          Adj Close
# count  4303.000000
# mean    764.719805
# std     156.977364
# min     419.950012
# 25%     639.404998
# 50%     754.700012
# 75%     878.984985
# max    1147.839966

# %%
euronext_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4303 entries, 0 to 4302
# Data columns (total 7 columns):
# Date         4303 non-null object
# Open         4303 non-null float64
# High         4303 non-null float64
# Low          4303 non-null float64
# Close        4303 non-null float64
# Volume       4303 non-null int64
# Adj Close    4303 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 235.4+ KB

# %% [markdown]
# ### Initial look at S&P 500 data

# %%
sp_df = pd.read_csv("SP500.csv", encoding = "utf8")
sp_df.head()
# Out:
#          Date         Open         High          Low        Close      Volume  \
# 0  2016-10-20  2142.510010  2147.179932  2133.439941  2141.340088  3337170000
# 1  2016-10-19  2140.810059  2148.439941  2138.149902  2144.290039  3362670000
# 2  2016-10-18  2138.310059  2144.379883  2135.489990  2139.600098  3170000000
# 3  2016-10-17  2132.949951  2135.610107  2124.429932  2126.500000  2830390000
# 4  2016-10-14  2139.679932  2149.189941  2132.979980  2132.979980  3228150000
#
#      Adj Close
# 0  2141.340088
# 1  2144.290039
# 2  2139.600098
# 3  2126.500000
# 4  2132.979980

# %%
sp_df.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count  16810.000000  16810.000000  16810.000000  16810.000000  1.681000e+04
# mean     503.321826    506.460830    500.011031    503.444687  8.346302e+08
# std      580.045806    583.383337    576.440576    580.162128  1.492149e+09
# min       16.660000     16.660000     16.660000     16.660000  6.800000e+05
# 25%       84.322500     85.150002     83.732502     84.322500  8.087500e+06
# 50%      154.650002    155.294998    153.995002    154.784996  7.834000e+07
# 75%      996.774978   1006.182510    987.882477    997.379989  9.061500e+08
# max     2187.810059   2193.810059   2186.800049   2190.149902  1.145623e+10
#
#           Adj Close
# count  16810.000000
# mean     503.444687
# std      580.162128
# min       16.660000
# 25%       84.322500
# 50%      154.784996
# 75%      997.379989
# max     2190.149902

# %%
sp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16810 entries, 0 to 16809
# Data columns (total 7 columns):
# Date         16810 non-null object
# Open         16810 non-null float64
# High         16810 non-null float64
# Low          16810 non-null float64
# Close        16810 non-null float64
# Volume       16810 non-null int64
# Adj Close    16810 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 919.4+ KB

# %% [markdown]
# ### Initial look at Brazil's data

# %%
brazil_df = pd.read_csv("Brazil.csv", encoding = "utf8")
brazil_df.head()
# Out:
#          Date     Open     High      Low    Close   Volume  Adj Close
# 0  2016-10-20  63495.0  63927.0  62729.0  63838.0  3421500    63838.0
# 1  2016-10-19  63784.0  64089.0  63309.0  63506.0  3614000    63506.0
# 2  2016-10-18  62701.0  63937.0  62701.0  63782.0  4390300    63782.0
# 3  2016-10-17  61768.0  62696.0  61719.0  62696.0  3340700    62696.0
# 4  2016-10-14  61120.0  62039.0  61120.0  61767.0  3691200    61767.0

# %%
brazil_df.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   5833.000000   5833.000000   5833.000000   5833.000000  5.833000e+03
# mean   36884.621638  37293.700844  36430.946163  36880.125322  5.459046e+06
# std    21404.071965  21553.180185  21181.095392  21377.921581  2.261244e+07
# min      237.000008    242.000008    237.000008    237.000008  0.000000e+00
# 25%    14266.000000  14474.000000  14056.000000  14282.000000  0.000000e+00
# 50%    39930.000000  40498.000000  39226.999512  39947.000000  0.000000e+00
# 75%    55137.000000  55756.000977  54537.000000  55112.000000  2.428400e+06
# max    94230.000000  94230.000000  91800.000000  94190.000000  2.322653e+08
#
#           Adj Close
# count   5833.000000
# mean   31327.632333
# std    22716.567406
# min       23.700001
# 25%    10614.000000
# 50%    24855.000000
# 75%    53689.000000
# max    73517.000000

# %%
brazil_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5833 entries, 0 to 5832
# Data columns (total 7 columns):
# Date         5833 non-null object
# Open         5833 non-null float64
# High         5833 non-null float64
# Low          5833 non-null float64
# Close        5833 non-null float64
# Volume       5833 non-null int64
# Adj Close    5833 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 319.1+ KB

# %% [markdown]
# ### Initial look at HongKong's data

# %%
hongkong_df = pd.read_csv("HongKong.csv", encoding = "latin1") # or utf8
hongkong_df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-10-20  23412.679688  23500.820312  23360.550781  23374.400391
# 1  2016-10-19  23393.800781  23445.560547  23234.669922  23304.970703
# 2  2016-10-18  23130.199219  23402.890625  23130.199219  23394.390625
# 3  2016-10-17  23164.539062  23177.189453  22978.009766  23037.539062
# 4  2016-10-14  23119.960938  23318.359375  23087.140625  23233.310547
#
#        Volume     Adj Close
# 0  1091055700  23374.400391
# 1  1009919700  23304.970703
# 2  1423480700  23394.390625
# 3  1121480100  23037.539062
# 4  1500768600  23233.310547

# %%
hongkong_df.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   7412.000000   7412.000000   7412.000000   7412.000000  7.412000e+03
# mean   13452.629292  13542.173461  13348.260037  13448.009196  6.638751e+08
# std     7143.524610   7184.168524   7089.516400   7135.962767  9.527950e+08
# min     1950.500000   1950.500000   1894.900024   1894.900024  0.000000e+00
# 25%     8514.099609   8597.160156   8420.692383   8506.492431  0.000000e+00
# 50%    12997.100098  13095.379883  12879.349609  12999.100097  1.456581e+08
# 75%    20342.675293  20454.248047  20166.504883  20318.709473  1.337093e+09
# max    31783.470703  31958.410156  31361.910156  31638.220703  9.799120e+09
#
#           Adj Close
# count   7412.000000
# mean   13448.009196
# std     7135.962767
# min     1894.900024
# 25%     8506.492431
# 50%    12999.100097
# 75%    20318.709473
# max    31638.220703

# %%
hongkong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7412 entries, 0 to 7411
# Data columns (total 7 columns):
# Date         7412 non-null object
# Open         7412 non-null float64
# High         7412 non-null float64
# Low          7412 non-null float64
# Close        7412 non-null float64
# Volume       7412 non-null int64
# Adj Close    7412 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 405.4+ KB

# %% [markdown]
# ## Merge all the dataframes into giant one, indexed by date

# %%
dfs = [sp_df, euronext_df, brazil_df, hongkong_df]

# %%
for df in dfs:
    print(df.columns)

for df in dfs:
    df["Date"] = pd.to_datetime(df["Date"])
    df.index = df["Date"]
    del df["Date"]
    print(df.dtypes)

for df in dfs:
    print(df.columns)
# Out:
# Index([u'Date', u'Open', u'High', u'Low', u'Close', u'Volume', u'Adj Close'], dtype='object')
# Index([u'Date', u'Open', u'High', u'Low', u'Close', u'Volume', u'Adj Close'], dtype='object')
# Index([u'Date', u'Open', u'High', u'Low', u'Close', u'Volume', u'Adj Close'], dtype='object')
# Index([u'Date', u'Open', u'High', u'Low', u'Close', u'Volume', u'Adj Close'], dtype='object')
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object
# ...

# %% [markdown]
# ### Rename the columns to reflect the dataset they came from

# %%
# dfs = [sp_df, euronext_df, brazil_df, hongkong_df]
dfs_names = ["SP", "EU", "BR", "HK"]
dfs_columns = ["Open", "High", "Low", "Close", "Volume", "Adj Close"]

col_names = []
for x in dfs_names:
    for y in dfs_columns:
        col_names.append(x+"-"+y)
col_names
# Out:
# [u'SP-Open',
#  u'SP-High',
#  u'SP-Low',
#  u'SP-Close',
#  u'SP-Volume',
#  u'SP-Adj Close',
#  u'EU-Open',
#  u'EU-High',
#  u'EU-Low',
#  u'EU-Close',
#  u'EU-Volume',
#  u'EU-Adj Close',
#  u'BR-Open',
#  u'BR-High',
#  u'BR-Low',
#  u'BR-Close',
#  u'BR-Volume',
#  u'BR-Adj Close',
#  u'HK-Open',
#  u'HK-High',
#  u'HK-Low',
#  u'HK-Close',
#  u'HK-Volume',
#  u'HK-Adj Close']

# %%
all_df = pd.concat(dfs, axis=1)
all_df.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close  Open  High  Low  \
# Date
# 1950-01-03  16.66  16.66  16.66  16.66  1260000.0      16.66   NaN   NaN  NaN
# 1950-01-04  16.85  16.85  16.85  16.85  1890000.0      16.85   NaN   NaN  NaN
# 1950-01-05  16.93  16.93  16.93  16.93  2550000.0      16.93   NaN   NaN  NaN
# 1950-01-06  16.98  16.98  16.98  16.98  2010000.0      16.98   NaN   NaN  NaN
# 1950-01-09  17.08  17.08  17.08  17.08  2520000.0      17.08   NaN   NaN  NaN
#
#             Close  Volume  Adj Close  Open  High  Low  Close  Volume  \
# Date
# 1950-01-03    NaN     NaN        NaN   NaN   NaN  NaN    NaN     NaN
# 1950-01-04    NaN     NaN        NaN   NaN   NaN  NaN    NaN     NaN
# 1950-01-05    NaN     NaN        NaN   NaN   NaN  NaN    NaN     NaN
# 1950-01-06    NaN     NaN        NaN   NaN   NaN  NaN    NaN     NaN
# 1950-01-09    NaN     NaN        NaN   NaN   NaN  NaN    NaN     NaN
#
#             Adj Close  Open  High  Low  Close  Volume  Adj Close
# ...

# %%
all_df.columns = col_names
all_df.head()
# Out:
#             SP-Open  SP-High  SP-Low  SP-Close  SP-Volume  SP-Adj Close  \
# Date
# 1950-01-03    16.66    16.66   16.66     16.66  1260000.0         16.66
# 1950-01-04    16.85    16.85   16.85     16.85  1890000.0         16.85
# 1950-01-05    16.93    16.93   16.93     16.93  2550000.0         16.93
# 1950-01-06    16.98    16.98   16.98     16.98  2010000.0         16.98
# 1950-01-09    17.08    17.08   17.08     17.08  2520000.0         17.08
#
#             EU-Open  EU-High  EU-Low  EU-Close  EU-Volume  EU-Adj Close  \
# Date
# 1950-01-03      NaN      NaN     NaN       NaN        NaN           NaN
# 1950-01-04      NaN      NaN     NaN       NaN        NaN           NaN
# 1950-01-05      NaN      NaN     NaN       NaN        NaN           NaN
# 1950-01-06      NaN      NaN     NaN       NaN        NaN           NaN
# 1950-01-09      NaN      NaN     NaN       NaN        NaN           NaN
#
#             BR-Open  BR-High  BR-Low  BR-Close  BR-Volume  BR-Adj Close  \
# Date
# ...

# %%
all_df.describe()
# Out:
#             SP-Open       SP-High        SP-Low      SP-Close     SP-Volume  \
# count  16810.000000  16810.000000  16810.000000  16810.000000  1.681000e+04
# mean     503.321826    506.460830    500.011031    503.444687  8.346302e+08
# std      580.045806    583.383337    576.440576    580.162128  1.492149e+09
# min       16.660000     16.660000     16.660000     16.660000  6.800000e+05
# 25%             NaN           NaN           NaN           NaN           NaN
# 50%             NaN           NaN           NaN           NaN           NaN
# 75%             NaN           NaN           NaN           NaN           NaN
# max     2187.810059   2193.810059   2186.800049   2190.149902  1.145623e+10
#
#        SP-Adj Close      EU-Open      EU-High       EU-Low     EU-Close  \
# count  16810.000000  4303.000000  4303.000000  4303.000000  4303.000000
# mean     503.444687   764.865235   769.284736   759.886435   764.719805
# ...

# %%
all_df.info()
#all_df.rename(columns =)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16998 entries, 1950-01-03 to 2016-10-20
# Data columns (total 24 columns):
# SP-Open         16810 non-null float64
# SP-High         16810 non-null float64
# SP-Low          16810 non-null float64
# SP-Close        16810 non-null float64
# SP-Volume       16810 non-null float64
# SP-Adj Close    16810 non-null float64
# EU-Open         4303 non-null float64
# EU-High         4303 non-null float64
# EU-Low          4303 non-null float64
# EU-Close        4303 non-null float64
# EU-Volume       4303 non-null float64
# EU-Adj Close    4303 non-null float64
# BR-Open         5833 non-null float64
# BR-High         5833 non-null float64
# BR-Low          5833 non-null float64
# BR-Close        5833 non-null float64
# BR-Volume       5833 non-null float64
# BR-Adj Close    5833 non-null float64
# HK-Open         7412 non-null float64
# HK-High         7412 non-null float64
# HK-Low          7412 non-null float64
# ...

# %%
all_df.to_csv("all.csv")

# %% [markdown]
# ## Make one giant plot

# %%
all_df[["SP-Close", "EU-Close", "BR-Close", "HK-Close"]].resample("D").mean().plot(figsize=(12, 6), logy=True)
#plt.yscale("log")
#plt.show()

# %% [markdown]
# ## And now some pivot tables

# %%
day_pivot = all_df.pivot_table(index=all_df.index.day, 
                               values=['SP-Open', 'SP-High', 'SP-Low', 'SP-Close', 'SP-Volume'], 
                               aggfunc=np.mean)
day_pivot
# Out:
#       SP-Close     SP-High      SP-Low     SP-Open     SP-Volume
# 1   502.126242  504.760039  497.834618  501.035557  8.569573e+08
# 2   502.895010  505.693731  499.272359  502.355209  8.279388e+08
# 3   502.518326  505.434935  498.922241  502.268907  8.272013e+08
# 4   512.011292  515.436001  508.371942  512.216315  8.838072e+08
# 5   507.155676  509.903850  503.265985  506.639815  8.316462e+08
# 6   500.774257  503.840464  497.165367  500.796083  8.458400e+08
# 7   507.177753  510.563850  504.197105  507.822788  8.615059e+08
# 8   508.650849  511.443040  504.973304  508.258323  8.463297e+08
# 9   501.911023  505.564727  499.150865  502.855097  8.277581e+08
# 10  501.298102  504.445467  497.926696  501.309032  8.298247e+08
# 11  508.316219  511.466891  504.941431  508.282562  8.271367e+08
# 12  512.958358  515.810877  509.281340  512.795036  8.361025e+08
# 13  501.765414  504.697318  498.267565  501.465874  8.211104e+08
# ...

# %%
day_pivot["SP-Volume"].plot()

# %%
month_pivot = all_df.pivot_table(index=all_df.index.month, 
                               values=['SP-Open', 'SP-High', 'SP-Low', 'SP-Close', 'SP-Volume'], 
                               aggfunc=np.mean)
month_pivot
# Out:
#       SP-Close     SP-High      SP-Low     SP-Open     SP-Volume
# 1   480.287251  483.410391  476.730100  480.336197  8.447794e+08
# 2   497.244177  500.100851  493.855293  497.159235  8.375633e+08
# 3   499.153772  502.033567  495.688346  498.790841  8.588660e+08
# 4   507.081536  509.931054  503.605845  506.752201  8.519139e+08
# 5   508.829591  511.685126  505.515628  508.704647  8.371580e+08
# 6   511.148855  514.196753  508.088570  511.211194  8.300688e+08
# 7   515.010665  517.826357  511.672771  514.891729  8.290884e+08
# 8   511.345436  514.531271  508.010872  511.485896  7.892435e+08
# 9   509.602933  512.975578  506.103799  509.768553  8.710000e+08
# 10  500.841896  504.325499  496.583704  500.536282  8.883174e+08
# 11  499.230902  502.137036  495.769508  498.936223  8.142390e+08
# 12  500.575741  503.356778  497.551562  500.303446  7.620885e+08

# %%
month_pivot["SP-Volume"].plot()

# %%
weekday_pivot = all_df.pivot_table(index=all_df.index.weekday, 
                               values=['SP-Open', 'SP-High', 'SP-Low', 'SP-Close', 'SP-Volume'], 
                               aggfunc=np.mean)
weekday_pivot
# Out:
#      SP-Close     SP-High      SP-Low     SP-Open     SP-Volume
# 0  495.690238  498.645668  492.465588  495.723636  7.638698e+08
# 1  506.341673  509.420603  502.854872  506.104582  8.427205e+08
# 2  506.868307  509.915679  503.376932  506.661133  8.614435e+08
# 3  504.498899  507.519021  500.906192  504.330917  8.635222e+08
# 4  503.389917  506.364489  500.028578  503.364855  8.379630e+08

# %%
weekday_pivot["SP-Volume"].plot(kind="bar")
pylab.xticks([0,1,2,3,4], ["Mon", "Tue", "Wed", "Thu", "Fri"])
pylab.show()

# %%
# Just ignore these, they don't work - Why?
# weekday_pivot["SP-Volume"].plot(kind="bar", columns=["Mon", "Tue", "Wed", "Thu", "Fri"])
# weekday_pivot["SP-Volume"].plot(kind="bar", xticks={0:"Mon", 1:"Tue", 2:"Wed", 3:"Thu", 4:"Fri"})
